# %%
# from controller import Controller
from coi_client import Controller


# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 5, 45, 85, 'teapot', 'cup','Pour water into a cup with a teapot'     # 橙色杯子倒水
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 6, 35, 30, 'teapot', 'cup','Pour water into a cup with a teapot'     # 白色杯子倒水
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj = 8, 25, 35, 'toy bear', None    # 玩具熊
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 10, 25, 50, 'toy box', None,'close the box'     # 关闭盒子
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 11, 85, 50, 'flower', 'vase','insert the flower into the vase'     
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 12, 50, 50, 'cup', 'box','put the cup onto the box'     

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 17, 30, 40, 'flower', 'white vase','insert the flower into the white vase'     
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 20, 10, 45, 'flower', 'textile vase','insert the flower into the white vase'  

# demo_scene_id, demo_start_id, demo_end_id, positive_obj, passive_obj, task = 19, 22, 62, 'flower', 'vase', 'insert the flower into the vase'     
# demo_scene_id, demo_start_id, demo_end_id, positive_obj, passive_obj, task = 21, 26, 58, 'flower', 'textile vase', 'insert the flower into the vase'     


# demo_scene_id, demo_start_id, demo_end_id,positive_ obj,passive_obj,task = 22, 23, 55, 'teapot', 'cup','Pour water into a cup with a teapot'     # 棕色杯子倒水
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 35, 60, 110, 'teapot', 'cup','Pour water into a cup with a teapot'     # 白色杯子倒水
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 36, 35, 85, 'teapot', 'cup','Pour water into a cup with a teapot'     # 棕色杯子倒水
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 37, 40, 94, 'teapot', 'cup','Pour water into a cup with a teapot'     # 棕色杯子倒水

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 23, 26, 47, 'toy box', None,'close the box'     # 关闭盒子

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 24, 23, 36, 'toy box', None,'close the box'     # 关闭盒子

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 25, 19, 62, 'toy bear', None,'Shake the hand of the toy bear'     # 摇动玩具熊的手

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 26, 46, 108, 'toy bear', None,'Shake the hand of the toy bear'     # 摇动玩具熊的手

#demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 27, 60, 164, 'cup', 'box','Put the cup onto the box'     # 摇动玩具熊的手

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 28, 50, 131, 'toy bear', None,'Shake the hand of the toy bear'     # 摇动玩具熊的手

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 29, 55, 156, 'toy bear', None,'Shake the hand of the toy bear'     # 摇动玩具熊的手

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 30, 45, 147, 'toy bear', None,'Shake the hand of the toy bear'     # 摇动玩具熊的手

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 31, 55, 148, 'cup', 'box','Put the cup onto the box'    #把杯子放到盒子上

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 39, 44, 158, 'cup', 'box','Put the cup onto the box'    #把杯子放到盒子上


# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 32, 19, 39, 'bottle', None,'stand up the lying bottle'   # 把躺着的瓶子立起来


# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 33, 24, 47, 'stapler', None,'close the stapler' # 关闭订书机


# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 34, 25, 50, 'bottle', None,'stand up the lying bottle'   # 把躺着的瓶子立起来


# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 40, 48, 137, 'cup', 'box','Put the cup onto the box'    #把杯子放到盒子上

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 41, 47, 134, 'bottle', 'box','stand up the lying bottle on the box'    #把盒子上的杯子立起来
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 42, 42, 125, 'bottle', 'box','stand up the lying bottle on the box'    #把盒子上的杯子立起来
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 46, 40, 80, 'glasses frames', None,'close the glasses'
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 47, 30, 65, 'glasses frames', None,'close the glasses'
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 48, 55, 75, 'heterogeneous stapler', None,'open the stapler'
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 49, 45, 85, 'heterogeneous stapler', None,'open the stapler'

demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 50, 35, 85, 'teapot', 'cup', 'Pour water into a cup with a teapot'    # 比较好看的demo

# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 116, 55, 105, 'box', None, 'close the box'   # world model fail
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 117, 35, 75, 'box', None, 'close the box'   # world model success
# 118插花，不用看都知道失败
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 119, 30, 80, 'flower', 'vase', 'insert the flower into the vase'   # world model tracking fail
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 120, 30, 80, 'flower', 'vase', 'insert the flower into the vase'   # world model tracking fail
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 121, 40, 100, 'teapot', 'cup', 'Pour water into a cup with a teapot'   # world model success 
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 122, 30, 75, 'teapot', 'cup', 'Pour water into a cup with a teapot'   # world model 半成功吧 
# demo_scene_id, demo_start_id, demo_end_id,positive_obj,passive_obj,task = 123, 60, 140, 'red cup', 'box', 'Put the cup onto the box'   # world model 半成功吧 



# 注意！！！！！！！！第一帧最好不要遮挡
controller = Controller(demo_scene_id=demo_scene_id, demo_start_id=demo_start_id, demo_end_id=demo_end_id,dynamic_keypoint=False,positive_obj=positive_obj,passive_obj=passive_obj,task=task)    
controller.execute()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# load checkpoint ./hand_object_detector/models/res101_handobj_100K/pascal_voc/faster_rcnn_1_8_132028.pth
# load model successfully!
# WARNING:root:autolab_core not installed as catkin package, RigidTransform ros methods will be unavailable
# Controller init
# dynamic_keypoint: False
# Observer init
# cam1 intrinsic: {'fx': 607.1639404296875, 'fy': 606.1770629882812, 'cx': 327.6490783691406, 'cy': 236.9655303955078, 'height': 480, 'weight': 640}
# cam2 intrinsic: {'fx': 607.226806640625, 'fy': 606.3204345703125, 'cx': 311.2171325683594, 'cy': 232.13575744628906, 'height': 480, 'weight': 640}
# /home/yan20/Desktop/feepe/107/dinov2/dinov2/layers/swiglu_ffn.py:43: UserWarning: xFormers is available (SwiGLU)
#   warnings.warn("xFormers is available (SwiGLU)")
# ...
